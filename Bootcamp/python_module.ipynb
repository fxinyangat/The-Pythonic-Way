# %% [markdown]
# ## Python OS Module
#
# OS module allows you to perform tasks such as file and directory manipulation, environment variables access and process management

# %%
# Get location of cuurent working directory
import os

homedir=os.getcwd()

homedir
# Out:
# '/Users/xavierinyangat/Documents/Lessons/Python/Bootcamp'

# %%
#creating a directory

os.mkdir(f"{homedir}/data/files")

# %%
# Change a Directory
# enter the data directory
os.chdir("/Users/xavierinyangat/Documents/Lessons/Python/Bootcamp")

# %%
# Listing Out files and directories
new_dir = os.chdir("/Users/xavierinyangat/Documents/Lessons/Python/Bootcamp/data/files")

os.getcwd()

os.listdir()
# Out:
# []

# %%
# see files in the cwd
for i in os.listdir():
    print(i)

    # delete/read a file

    if i == 'hello.txt':
        i.remove()

# %%
# Deleting Directory or Files using Python
