# %% [markdown]
# ## Date and Time
#
# Python provides date time module to work with dates and times. It allows us to manipulate and format date and time values efficiently

# %% [markdown]
# #### Creating Date Objects
# To create a date, we can use the datetime() class (constructor) of the datetime module.
#
# The datetime() class requires three parameters to create a date: year, month, day

# %%
import datetime

x = datetime.datetime.now()

print(x)
# Out:
# 2025-12-01 10:47:55.157198

# %% [markdown]
# #### The strftime() Method
#
# The datetime object has a method for formatting date objects into readable strings.
#
# The method is called strftime(), and takes one parameter, format, to specify the format of the returned string:

# %%
import datetime

x = datetime.datetime(1998, 11, 30)

print(f"Month:{x.strftime("%B")}")

print(f"Weekday:{x.strftime("%A")}")
print(f"Day of Month:{x.strftime("%d")}")
print(f"Year:{x.strftime("%Y")}")
# Out:
# Month:November
# Weekday:Monday
# Day of Month:30
# Year:1998

# %%
from datetime import date

# get todays date
today = date.today()

print(f"The date today is {today}")
# Out:
# The date today is 2025-12-01

# %%
# create a specific date

custom_date = date(1998, 11, 30)

print(custom_date)
# Out:
# 1998-11-30

# %%
# creating a date time object
from datetime import datetime
now = datetime.now()

print(now)
# Out:
# 2025-12-01 10:56:01.517766

# %%
# custom datetime 

custom_datetime = datetime(2024,2,6,14,30,15)

print(f"custom datetime {custom_datetime}")
# Out:
# custom datetime 2024-02-06 14:30:15

# %%
#formating date and time
date_string = "2024-12-06 14:30:15"
print(type(date_string))

parsed_datetime = datetime.strptime(date_string,"%Y-%m-%d %H:%M:%S") #we use string parse for string formats.
print(f"Parsed date {parsed_datetime}")
#another example
formated_date = now.strftime("%Y-%b-%d %H:%M:%S")
print(formated_date)
# Out:
# <class 'str'>
# Parsed date 2024-12-06 14:30:15
# 2025-Dec-01 10:56:01

# %%
# PErform date arithmetic

from datetime import timedelta

five_days_from_now = now + timedelta(days = 5)

print(five_days_from_now)


two_hrs_ago = now - timedelta(hours=2)
print(two_hrs_ago)
# Out:
# 2025-12-06 10:56:01.517766
# 2025-12-01 08:56:01.517766
